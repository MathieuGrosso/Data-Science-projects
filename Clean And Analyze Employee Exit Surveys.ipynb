# %% [markdown]
# # Department of Education, Training and Employment (DETE)  &  the Technical and Further Education (TAFE)
#
#  * Are **employees** who only worked for the institutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been there longer?
#
#  * Are younger employees resigning due to some kind of   dissatisfaction? What about older employees?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

dete_survey=pd.read_csv('dete_survey.csv')
tafe_survey=pd.read_csv('tafe_survey.csv')

# %%
dete_survey.info()

print('head of dete_survey')
dete_survey.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 822 entries, 0 to 821
# Data columns (total 56 columns):
# ID                                     822 non-null int64
# SeparationType                         822 non-null object
# Cease Date                             822 non-null object
# DETE Start Date                        822 non-null object
# Role Start Date                        822 non-null object
# Position                               817 non-null object
# Classification                         455 non-null object
# Region                                 822 non-null object
# Business Unit                          126 non-null object
# Employment Status                      817 non-null object
# Career move to public sector           822 non-null bool
# Career move to private sector          822 non-null bool
# Interpersonal conflicts                822 non-null bool
# Job dissatisfaction                    822 non-null bool
# ...

# %%
print('value count') 
dete_survey.columns.value_counts()
# Out:
# value count
# Gender                                 1
# My say                                 1
# Relocation                             1
# Study/Travel                           1
# Kept informed                          1
# Lack of recognition                    1
# Dissatisfaction with the department    1
# Further PD                             1
# Professional Development               1
# ID                                     1
# Interpersonal conflicts                1
# None of the above                      1
# Career Aspirations                     1
# Communication                          1
# Skills                                 1
# Workplace issue                        1
# Disability                             1
# Work location                          1
# Role Start Date                        1
# Physical work environment              1
# Physical environment                   1
# Coach                                  1
# ...

# %%
print('valeur nul')
dete_survey.isnull()
# Out:
# valeur nul
#         ID  SeparationType  Cease Date  DETE Start Date  Role Start Date  \
# 0    False           False       False            False            False
# 1    False           False       False            False            False
# 2    False           False       False            False            False
# 3    False           False       False            False            False
# 4    False           False       False            False            False
# 5    False           False       False            False            False
# 6    False           False       False            False            False
# 7    False           False       False            False            False
# 8    False           False       False            False            False
# 9    False           False       False            False            False
# 10   False           False       False            False            False
# 11   False           False       False            False            False
# ...

# %%
tafe_survey.info()

#head of dete_survey
tafe_survey.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 702 entries, 0 to 701
# Data columns (total 72 columns):
# Record ID                                                                                                                                                        702 non-null float64
# Institute                                                                                                                                                        702 non-null object
# WorkArea                                                                                                                                                         702 non-null object
# CESSATION YEAR                                                                                                                                                   695 non-null float64
# ...

# %%
#value count 
tafe_survey.columns.value_counts()

#valeur nul
tafe_survey.isnull()
# Out:
#      Record ID  Institute  WorkArea  CESSATION YEAR  \
# 0        False      False     False           False
# 1        False      False     False           False
# 2        False      False     False           False
# 3        False      False     False           False
# 4        False      False     False           False
# 5        False      False     False           False
# 6        False      False     False           False
# 7        False      False     False           False
# 8        False      False     False           False
# 9        False      False     False           False
# 10       False      False     False           False
# 11       False      False     False           False
# 12       False      False     False           False
# 13       False      False     False           False
# 14       False      False     False           False
# 15       False      False     False           False
# 16       False      False     False           False
# ...

# %%
dete_survey=pd.read_csv('dete_survey.csv',na_values='Not Stated')
dete_survey.head(5)
# Out:
#    ID                    SeparationType Cease Date  DETE Start Date  \
# 0   1             Ill Health Retirement    08/2012           1984.0
# 1   2  Voluntary Early Retirement (VER)    08/2012              NaN
# 2   3  Voluntary Early Retirement (VER)    05/2012           2011.0
# 3   4         Resignation-Other reasons    05/2012           2005.0
# 4   5                    Age Retirement    05/2012           1970.0
#
#    Role Start Date                                      Position  \
# 0           2004.0                                Public Servant
# 1              NaN                                Public Servant
# 2           2011.0                               Schools Officer
# 3           2006.0                                       Teacher
# 4           1989.0  Head of Curriculum/Head of Special Education
#
#   Classification              Region                      Business Unit  \
# 0        A01-A04      Central Office  Corporate Strategy and Peformance
# ...

# %%
cols=dete_survey.columns[28:49]
dete_survey_updated=dete_survey.drop(cols,axis=1)

# %%
tafe_survey_updated=tafe_survey.drop(tafe_survey.columns[17:66],axis=1)

# %%
dete_survey_updated.columns.str.replace(" ","_").str.strip().str.lower()
# Out:
# Index(['id', 'separationtype', 'cease_date', 'dete_start_date',
#        'role_start_date', 'position', 'classification', 'region',
#        'business_unit', 'employment_status', 'career_move_to_public_sector',
#        'career_move_to_private_sector', 'interpersonal_conflicts',
#        'job_dissatisfaction', 'dissatisfaction_with_the_department',
#        'physical_work_environment', 'lack_of_recognition',
#        'lack_of_job_security', 'work_location', 'employment_conditions',
#        'maternity/family', 'relocation', 'study/travel', 'ill_health',
#        'traumatic_incident', 'work_life_balance', 'workload',
#        'none_of_the_above', 'gender', 'age', 'aboriginal', 'torres_strait',
#        'south_sea', 'disability', 'nesb'],
#       dtype='object')

# %%
dete_survey_updated.columns=dete_survey_updated.columns.str.replace(" ","_").str.strip().str.lower()

# %%
dete_survey_updated
# Out:
#       id                        separationtype cease_date  dete_start_date  \
# 0      1                 Ill Health Retirement    08/2012           1984.0
# 1      2      Voluntary Early Retirement (VER)    08/2012              NaN
# 2      3      Voluntary Early Retirement (VER)    05/2012           2011.0
# 3      4             Resignation-Other reasons    05/2012           2005.0
# 4      5                        Age Retirement    05/2012           1970.0
# 5      6             Resignation-Other reasons    05/2012           1994.0
# 6      7                        Age Retirement    05/2012           1972.0
# 7      8                        Age Retirement    05/2012           1988.0
# 8      9             Resignation-Other reasons    07/2012           2009.0
# 9     10            Resignation-Other employer       2012           1997.0
# 10    11                        Age Retirement       2012           1999.0
# ...

# %%
dictionary={'Record ID': 'id', 'CESSATION YEAR': 'cease_date', 'Reason for ceasing employment': 'separationtype', 'Gender. What is your Gender?': 'gender', 'CurrentAge. Current Age': 'age', 'Employment Type. Employment Type': 'employment_status', 'Classification. Classification': 'position', 'LengthofServiceOverall. Overall Length of Service at Institute (in years)': 'institute_service', 'LengthofServiceCurrent. Length of Service at current workplace (in years)': 'role_service'}

# %%
tafe_survey_updated = tafe_survey_updated.rename(columns=dictionary)

# %%
tafe_survey_updated.head(5)
# Out:
#              id                              Institute  \
# 0  6.341330e+17  Southern Queensland Institute of TAFE
# 1  6.341337e+17            Mount Isa Institute of TAFE
# 2  6.341388e+17            Mount Isa Institute of TAFE
# 3  6.341399e+17            Mount Isa Institute of TAFE
# 4  6.341466e+17  Southern Queensland Institute of TAFE
#
#                    WorkArea  cease_date    separationtype  \
# 0  Non-Delivery (corporate)      2010.0  Contract Expired
# 1  Non-Delivery (corporate)      2010.0        Retirement
# 2       Delivery (teaching)      2010.0        Retirement
# 3  Non-Delivery (corporate)      2010.0       Resignation
# 4       Delivery (teaching)      2010.0       Resignation
#
#   Contributing Factors. Career Move - Public Sector   \
# 0                                                NaN
# 1                                                  -
# 2                                                  -
# 3                                                  -
# ...

# %% [markdown]
# # removing data we don't need:

# %%
dete_survey_updated.columns.value_counts()
# Out:
# work_life_balance                      1
# nesb                                   1
# physical_work_environment              1
# lack_of_recognition                    1
# id                                     1
# work_location                          1
# age                                    1
# study/travel                           1
# torres_strait                          1
# job_dissatisfaction                    1
# classification                         1
# dissatisfaction_with_the_department    1
# interpersonal_conflicts                1
# employment_status                      1
# aboriginal                             1
# ill_health                             1
# workload                               1
# business_unit                          1
# region                                 1
# relocation                             1
# south_sea                              1
# none_of_the_above                      1
# disability                             1
# ...

# %%
tafe_survey_updated.columns.value_counts()
# Out:
# Institute                                              1
# Contributing Factors. Career Move - Public Sector      1
# employment_status                                      1
# position                                               1
# cease_date                                             1
# Contributing Factors. Career Move - Private Sector     1
# role_service                                           1
# Contributing Factors. NONE                             1
# Contributing Factors. Job Dissatisfaction              1
# Contributing Factors. Career Move - Self-employment    1
# Contributing Factors. Ill Health                       1
# gender                                                 1
# Contributing Factors. Maternity/Family                 1
# separationtype                                         1
# id                                                     1
# institute_service                                      1
# ...

# %%
pattern = r"[Rr]esignation"
dete_resignations = dete_survey_updated[dete_survey_updated['separationtype'].str.contains(pattern)].copy()
tafe_resignations=tafe_survey_updated[dete_survey_updated['separationtype'].str.contains(pattern)].copy()
# Out:
# /dataquest/system/env/python3/lib/python3.4/site-packages/ipykernel/__main__.py:3: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
dete_resignations.head()
# Out:
#     id                        separationtype cease_date  dete_start_date  \
# 3    4             Resignation-Other reasons    05/2012           2005.0
# 5    6             Resignation-Other reasons    05/2012           1994.0
# 8    9             Resignation-Other reasons    07/2012           2009.0
# 9   10            Resignation-Other employer       2012           1997.0
# 11  12  Resignation-Move overseas/interstate       2012           2009.0
#
#     role_start_date          position classification                region  \
# 3            2006.0           Teacher        Primary    Central Queensland
# 5            1997.0  Guidance Officer            NaN        Central Office
# 8            2009.0           Teacher      Secondary      North Queensland
# 9            2008.0      Teacher Aide            NaN                   NaN
# 11           2009.0           Teacher      Secondary  Far North Queensland
#
#            business_unit    employment_status  ...   work_life_balance  \
# ...

# %% [markdown]
# # verify the data

# %%
dete_resignations['cease_date'].value_counts()
# Out:
# 2012       126
# 2013        74
# 01/2014     22
# 12/2013     17
# 06/2013     14
# 09/2013     11
# 11/2013      9
# 07/2013      9
# 10/2013      6
# 08/2013      4
# 05/2012      2
# 05/2013      2
# 2010         1
# 07/2006      1
# 09/2010      1
# 07/2012      1
# Name: cease_date, dtype: int64

# %%
pattern=r"(?P<Year>[1-2][0-9]{3})"

dete_resignations['cease_date']=dete_resignations['cease_date'].str.extract(pattern,expand=True).astype(float)

# %%
dete_resignations.head(5)
# Out:
#     id                        separationtype  cease_date  dete_start_date  \
# 3    4             Resignation-Other reasons      2012.0           2005.0
# 5    6             Resignation-Other reasons      2012.0           1994.0
# 8    9             Resignation-Other reasons      2012.0           2009.0
# 9   10            Resignation-Other employer      2012.0           1997.0
# 11  12  Resignation-Move overseas/interstate      2012.0           2009.0
#
#     role_start_date          position classification                region  \
# 3            2006.0           Teacher        Primary    Central Queensland
# 5            1997.0  Guidance Officer            NaN        Central Office
# 8            2009.0           Teacher      Secondary      North Queensland
# 9            2008.0      Teacher Aide            NaN                   NaN
# 11           2009.0           Teacher      Secondary  Far North Queensland
#
# ...

# %%
dete_resignations['cease_date'].astype(float)
# Out:
# 3      2012.0
# 5      2012.0
# 8      2012.0
# 9      2012.0
# 11     2012.0
# 12     2012.0
# 14     2012.0
# 16     2012.0
# 20     2012.0
# 21     2012.0
# 22     2012.0
# 23     2012.0
# 25     2012.0
# 27     2012.0
# 33     2012.0
# 34     2012.0
# 37     2012.0
# 39     2012.0
# 40     2012.0
# 41     2012.0
# 42     2012.0
# 43     2012.0
# 48     2012.0
# 50     2012.0
# 51     2012.0
# 55     2012.0
# 57     2012.0
# 61     2012.0
# 69     2012.0
# 71     2012.0
#         ...
# 747    2014.0
# 751    2013.0
# 752    2013.0
# 753    2013.0
# 755    2013.0
# 762    2006.0
# 766    2014.0
# 769    2013.0
# 770       NaN
# 771    2014.0
# 774       NaN
# 784    2013.0
# 786    2014.0
# 788       NaN
# 789    2014.0
# 790    2014.0
# 791       NaN
# 794    2013.0
# 797       NaN
# 798       NaN
# 802    2013.0
# 803    2014.0
# 804    2014.0
# 806    2013.0
# 807    2013.0
# 808    2013.0
# 815    2014.0
# 816    2014.0
# 819    2014.0
# 821    2013.0
# ...

# %%
dete_resignations['cease_date'].value_counts().sort_index(ascending=True)
# Out:
# 2006.0      1
# 2010.0      2
# 2012.0    129
# 2013.0    146
# 2014.0     22
# Name: cease_date, dtype: int64

# %%
dete_resignations['dete_start_date'].value_counts().sort_index(ascending=True)
# Out:
# 1963.0     1
# 1971.0     1
# 1972.0     1
# 1973.0     1
# 1974.0     2
# 1975.0     1
# 1976.0     2
# 1977.0     1
# 1980.0     5
# 1982.0     1
# 1983.0     2
# 1984.0     1
# 1985.0     3
# 1986.0     3
# 1987.0     1
# 1988.0     4
# 1989.0     4
# 1990.0     5
# 1991.0     4
# 1992.0     6
# 1993.0     5
# 1994.0     6
# 1995.0     4
# 1996.0     6
# 1997.0     5
# 1998.0     6
# 1999.0     8
# 2000.0     9
# 2001.0     3
# 2002.0     6
# 2003.0     6
# 2004.0    14
# 2005.0    15
# 2006.0    13
# 2007.0    21
# 2008.0    22
# 2009.0    13
# 2010.0    17
# 2011.0    24
# 2012.0    21
# 2013.0    10
# Name: dete_start_date, dtype: int64

# %%
tafe_resignations['cease_date'].value_counts().sort_index(ascending=True)
# Out:
# 2009.0     2
# 2010.0    37
# 2011.0    92
# 2012.0    93
# 2013.0    41
# Name: cease_date, dtype: int64

# %%
tafe_resignations.boxplot(column=['cease_date'])
plt.show()

# %% [markdown]
# * There aren't any major issues with the years.
# * The years in each dataframe don't span quite the same number of years. We'll leave it up to your discretion to drop any years you don't think are needed for the analysis.

# %% [markdown]
# # create a new column
# * Are employees who have only worked for the institutes for a short period of time resigning due to some kind of dissatisfaction? What about employees who have been at the job longer?

# %%
dete_resignations['institute_service']=dete_resignations['cease_date']-dete_resignations['dete_start_date']

# %%
dete_resignations['institute_service'].head(5)
# Out:
# 3      7.0
# 5     18.0
# 8      3.0
# 9     15.0
# 11     3.0
# Name: institute_service, dtype: float64

# %% [markdown]
# *we created a new institute_service column that we'll use to analyze survey respondents according to their length of employment*

# %% [markdown]
# *Next, we'll identify any employees who resigned because they were dissatisfied.*

# %%
def update_vals(val_col):
    if pd.isnull(val_col):
        return np.NaN
    elif val_col == '-':
        return False
    else:
        return True

# %%
tafe_cols = ['Contributing Factors. Dissatisfaction', 'Contributing Factors. Job Dissatisfaction']

# %%
tafe_resignations[tafe_cols] = tafe_resignations[tafe_cols].applymap(update_vals)

# %%
tafe_resignations[tafe_cols].head(100)
# Out:
#     Contributing Factors. Dissatisfaction  \
# 3                                   False
# 5                                   False
# 8                                   False
# 9                                   False
# 11                                    NaN
# 12                                    NaN
# 14                                   True
# 16                                    NaN
# 20                                   True
# 21                                  False
# 22                                  False
# 23                                  False
# 25                                    NaN
# 27                                  False
# 33                                  False
# 34                                  False
# 37                                  False
# 39                                  False
# 40                                   True
# 41                                  False
# 42                                  False
# ...

# %%
tafe_resignations['Contributing Factors. Job Dissatisfaction'].value_counts(dropna=False)
# Out:
# False    141
# NaN       97
# True      30
# Name: Contributing Factors. Job Dissatisfaction, dtype: int64

# %%
tafe_resignations['dissatisfied']=tafe_resignations[tafe_cols].any(axis=1,skipna=False)

# %%
tafe_resignations_up=tafe_resignations.copy()

# %%
dete_cols=['job_dissatisfaction','dissatisfaction_with_the_department','physical_work_environment','lack_of_recognition','lack_of_job_security','work_location','employment_conditions','work_life_balance','workload']

# %%
dete_resignations[dete_cols].head(5)
# Out:
#     job_dissatisfaction  dissatisfaction_with_the_department  \
# 3                 False                                False
# 5                 False                                False
# 8                 False                                False
# 9                  True                                 True
# 11                False                                False
#
#     physical_work_environment  lack_of_recognition  lack_of_job_security  \
# 3                       False                False                 False
# 5                       False                False                 False
# 8                       False                False                 False
# 9                       False                False                 False
# 11                      False                False                 False
#
#     work_location  employment_conditions  work_life_balance  workload
# 3           False                  False              False     False
# ...

# %%
dete_resignations['dissatisfied']=dete_resignations[dete_cols].any(axis=1,skipna=False)

# %%
dete_resignations_up=dete_resignations.copy()

# %% [markdown]
# *Now we now wheter or not someone has quit his job because of job dissatisfaction*
#
# *We can now go deeper!*

# %% [markdown]
# for now we have:
# * Renamed our columns
# * Dropped any data not needed for our analysis
# * Verified the quality of our data
# * Created a new institute_service column
# * Cleaned the Contributing Factors columns
# * Created a new column indicating if an employee resigned because they were dissatisfied in some way

# %% [markdown]
# # Let's combine our dataset !

# %%
dete_resignations_up['institute']='DETE'
dete_resignations_up.head(10)
# Out:
#     id                        separationtype  cease_date  dete_start_date  \
# 3    4             Resignation-Other reasons      2012.0           2005.0
# 5    6             Resignation-Other reasons      2012.0           1994.0
# 8    9             Resignation-Other reasons      2012.0           2009.0
# 9   10            Resignation-Other employer      2012.0           1997.0
# 11  12  Resignation-Move overseas/interstate      2012.0           2009.0
# 12  13             Resignation-Other reasons      2012.0           1998.0
# 14  15            Resignation-Other employer      2012.0           2007.0
# 16  17             Resignation-Other reasons      2012.0              NaN
# 20  21            Resignation-Other employer      2012.0           1982.0
# 21  22             Resignation-Other reasons      2012.0           1980.0
#
#     role_start_date          position classification  \
# 3            2006.0           Teacher        Primary
# ...

# %%
dete_resignations_up['institute'].head()
# Out:
# 3     DETE
# 5     DETE
# 8     DETE
# 9     DETE
# 11    DETE
# Name: institute, dtype: object

# %%
tafe_resignations_up['institute']='TAFE'

# %%
tafe_resignations.head(5)
# Out:
#               id                              Institute  \
# 3   6.341399e+17            Mount Isa Institute of TAFE
# 5   6.341475e+17  Southern Queensland Institute of TAFE
# 8   6.341579e+17  Southern Queensland Institute of TAFE
# 9   6.341588e+17         Barrier Reef Institute of TAFE
# 11  6.341719e+17         Barrier Reef Institute of TAFE
#
#                     WorkArea  cease_date            separationtype  \
# 3   Non-Delivery (corporate)      2010.0               Resignation
# 5        Delivery (teaching)      2010.0               Resignation
# 8        Delivery (teaching)      2009.0               Resignation
# 9   Non-Delivery (corporate)      2010.0               Resignation
# 11       Delivery (teaching)      2010.0  Retrenchment/ Redundancy
#
#    Contributing Factors. Career Move - Public Sector   \
# 3                                                   -
# 5                                                   -
# 8                                                   -
# ...

# %% [markdown]
# **We have add these column to be able to differentiate both datasets.**

# %%
combined=pd.concat([dete_resignations_up,tafe_resignations_up],axis=1)
combined
# Out:
#       id                        separationtype  cease_date  dete_start_date  \
# 3      4             Resignation-Other reasons      2012.0           2005.0
# 5      6             Resignation-Other reasons      2012.0           1994.0
# 8      9             Resignation-Other reasons      2012.0           2009.0
# 9     10            Resignation-Other employer      2012.0           1997.0
# 11    12  Resignation-Move overseas/interstate      2012.0           2009.0
# 12    13             Resignation-Other reasons      2012.0           1998.0
# 14    15            Resignation-Other employer      2012.0           2007.0
# 16    17             Resignation-Other reasons      2012.0              NaN
# 20    21            Resignation-Other employer      2012.0           1982.0
# 21    22             Resignation-Other reasons      2012.0           1980.0
# 22    23             Resignation-Other reasons      2012.0           1997.0
# ...

# %% [markdown]
# **we have combined our datasets**

# %%
combined_updated=combined.dropna(thresh=500,axis=1)
combined_updated

# %% [markdown]
# **We did not need these columns so we have removed any columns with less than 500 non null values**

# %%
combined_updated['institute_service']

# %%
pattern=
combined_updated['institute_service'].str.extract(pattern)
